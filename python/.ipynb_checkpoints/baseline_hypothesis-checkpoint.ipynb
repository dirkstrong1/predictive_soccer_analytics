# %%
from sqlalchemy import create_engine
import pandas as pd 
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
engine = create_engine('postgresql:///soccer_database')

# %%
df_epl = pd.read_sql_query('SELECT * FROM epl_2008_stats;', engine)

# %%
# df_epl

# %%
df_laliga = pd.read_sql_query('SELECT * FROM laliga_2008_stats;', engine)

# %%
# df_laliga

# %%
df_epl.columns
# Out:
# Index(['club', 'win', 'loss', 'draws', 'gol_for', 'gol_agst', 'gol_dif',
#        'pts'],
#       dtype='object')

# %%
fig, axs = plt.subplots(1, 2, gridspec_kw={'wspace': 2}, figsize=(10, 4))
(ax1, ax2) = axs
ax1.barh(df_epl['club'], df_epl['gol_dif'])
ax2.barh(df_laliga['club'], df_laliga['gol_dif'])
ax1.set_xlabel('Goals_difference')
ax2.set_xlabel('Goals_difference');

# %%
#H0 = League does not have any affect on total goal differential of that league.
#H1 = Total goal differential will vary by league.

# %%
epl_abs_goaldiff = np.absolute(df_epl['gol_dif'])
epl_abs_goaldiff.describe()
# Out:
# count    20.000000
# mean     20.600000
# std      14.154783
# min       0.000000
# 25%      10.250000
# 50%      19.000000
# 75%      29.500000
# max      50.000000
# Name: gol_dif, dtype: float64

# %%
laliga_abs_goaldiff = np.absolute(df_laliga['gol_dif'])
laliga_abs_goaldiff.describe()
# Out:
# count    20.000000
# mean     16.200000
# std      16.136262
# min       1.000000
# 25%       6.000000
# 50%      13.000000
# 75%      23.000000
# max      70.000000
# Name: gol_dif, dtype: float64

# %%
fig, axs = plt.subplots(1, 2, gridspec_kw={'wspace': 2}, figsize=(10, 4))
(ax1, ax2) = axs
ax1.barh(df_epl['club'], epl_abs_goaldiff)
ax2.barh(df_laliga['club'], laliga_abs_goaldiff)
ax1.set_xlabel('Abs goals difference')
ax2.set_xlabel('Abs goals difference');

# %%
import seaborn as sns

# %%
sns.distplot(laliga_abs_goaldiff, label='Laliga')
sns.distplot(epl_abs_goaldiff, label='EPL')
plt.legend()
plt.xlabel('Absolute goal difference')
plt.ylabel('Density');
# Out:
# //anaconda3/envs/learn-env/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#we are running a two-tail t-test
# signficant threshold (alpha) 0.01
alpha = 0.005

laliga_mean = laliga_abs_goaldiff.mean()

epl_mean = epl_abs_goaldiff.mean()

laliga_std = laliga_abs_goaldiff.std()

n = len(laliga_abs_goaldiff)

df = n-1

# %%
t_critical = stats.t.ppf(1-alpha, df)
t_critical
# Out:
# 2.860934606449914

# %%
laliga_epl_ttest = stats.ttest_1samp(a= laliga_abs_goaldiff, popmean= epl_mean)

# %%
t_value = laliga_epl_ttest[0]
p_value = laliga_epl_ttest[1]
p_value
# Out:
# 0.23759521514363574

# %%
if abs(t_value) > t_critical and p_value < alpha:
    print('Reject null hypthesis')
if abs(t) < t_critical:
    print('Dont reject null hypothesis')
# Out:
# Dont reject null hypothesis

# %%
## We conclude there is NO significant effect on goal differential due to league
